# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import gzip

# %%
#import data
file_path = './airbnb_dataset/Airbnb_Data.tar.gz'
with gzip.open(file_path, 'rt', encoding='utf-8') as f:
    df = pd.read_csv(f,low_memory=False)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Data Preprocessing

# %%
df.head()
# Out:
#    14fc7c55076590dad3ef272ad3efff7c.csv  log_price property_type  \
# 0                             6901257.0   5.010635     Apartment
# 1                             6304928.0   5.129899     Apartment
# 2                             7919400.0   4.976734     Apartment
# 3                            13418779.0   6.620073         House
# 4                             3808709.0   4.744932     Apartment
#
#          room_type                                          amenities  \
# 0  Entire home/apt  {"Wireless Internet","Air conditioning",Kitche...
# 1  Entire home/apt  {"Wireless Internet","Air conditioning",Kitche...
# 2  Entire home/apt  {TV,"Cable TV","Wireless Internet","Air condit...
# 3  Entire home/apt  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 4  Entire home/apt  {TV,Internet,"Wireless Internet","Air conditio...
#
#    accommodates  bathrooms  bed_type cancellation_policy cleaning_fee city  \
# 0           3.0        1.0  Real Bed              strict         True  NYC
# 1           7.0        1.0  Real Bed              strict         True  NYC
# 2           5.0        1.0  Real Bed            moderate         True  NYC
# 3           4.0        1.0  Real Bed            flexible         True   SF
# 4           2.0        1.0  Real Bed            moderate         True   DC
#
#                                          description first_review  \
# 0  Beautiful, sunlit brownstone 1-bedroom in the ...   2016-06-18
# 1  Enjoy travelling during your stay in Manhattan...   2017-08-05
# 2  The Oasis comes complete with a full backyard ...   2017-04-30
# 3  This light-filled home-away-from-home is super...          NaN
# 4  Cool, cozy, and comfortable studio located in ...   2015-05-12
#
#   host_has_profile_pic host_identity_verified host_response_rate  host_since  \
# 0                    t                      t                NaN  2012-03-26
# 1                    t                      f               100%  2017-06-19
# 2                    t                      t               100%  2016-10-25
# 3                    t                      t                NaN  2015-04-19
# 4                    t                      t               100%  2015-03-01
#
#   instant_bookable last_review   latitude   longitude  \
# 0                f  2016-07-18  40.696524  -73.991617
# 1                t  2017-09-23  40.766115  -73.989040
# 2                t  2017-09-14  40.808110  -73.943756
# 3                f         NaN  37.772004 -122.431619
# 4                t  2017-01-22  38.925627  -77.034596
#
#                                        name     neighbourhood  \
# 0            Beautiful brownstone 1-bedroom  Brooklyn Heights
# 1  Superb 3BR Apt Located Near Times Square    Hell's Kitchen
# 2                          The Garden Oasis            Harlem
# 3        Beautiful Flat in the Heart of SF!      Lower Haight
# 4                Great studio in midtown DC  Columbia Heights
#
#    number_of_reviews  review_scores_rating  \
# 0                2.0                 100.0
# 1                6.0                  93.0
# 2               10.0                  92.0
# 3                0.0                   NaN
# 4                4.0                  40.0
#
#                                        thumbnail_url  zipcode  bedrooms  beds
# 0  https://a0.muscache.com/im/pictures/6d7cbbf7-c...    11201       1.0   1.0
# 1  https://a0.muscache.com/im/pictures/348a55fe-4...    10019       3.0   3.0
# 2  https://a0.muscache.com/im/pictures/6fae5362-9...    10027       1.0   3.0
# 3  https://a0.muscache.com/im/pictures/72208dad-9...  94117.0       2.0   2.0
# 4                                                NaN    20009       0.0   1.0

# %%
df.shape
# Out:
# (74112, 29)

# %%
df.tail()
# Out:
#        14fc7c55076590dad3ef272ad3efff7c.csv  log_price property_type  \
# 74107                            13281809.0   5.043425     Apartment
# 74108                            18688039.0   5.220356     Apartment
# 74109                            17045948.0   5.273000     Apartment
# 74110                             3534845.0   4.852030          Boat
# 74111                                   NaN        NaN           NaN
#
#              room_type                                          amenities  \
# 74107  Entire home/apt  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 74108  Entire home/apt  {TV,Internet,"Wireless Internet","Air conditio...
# 74109  Entire home/apt  {TV,"Wireless Internet","Air conditioning",Kit...
# 74110  Entire home/apt  {TV,Internet,"Wireless Internet",Kitchen,"Free...
# 74111              NaN                                                NaN
#
#        accommodates  bathrooms  bed_type cancellation_policy cleaning_fee  \
# 74107           4.0        2.0  Real Bed            moderate         True
# 74108           5.0        1.0  Real Bed            moderate         True
# 74109           2.0        1.0  Real Bed              strict         True
# 74110           4.0        1.0  Real Bed            moderate        False
# 74111           NaN        NaN       NaN                 NaN          NaN
#
#       city                                        description first_review  \
# 74107   LA  Located on the Pacific Coast Highway, this apa...   2016-08-15
# 74108  NYC  A modern apartment located in East Williamsbur...   2015-01-03
# 74109  NYC  Fully renovated, designer's studio located in ...          NaN
# 74110   LA  You will stay-aboard the Island Trader at one ...   2013-09-05
# 74111  NaN                                                NaN          NaN
#
#       host_has_profile_pic host_identity_verified host_response_rate  \
# 74107                    t                      f               100%
# 74108                    t                      t               100%
# 74109                    t                      f               100%
# 74110                    t                      t               100%
# 74111                  NaN                    NaN                NaN
#
#        host_since instant_bookable last_review   latitude   longitude  \
# 74107  2016-05-03                f  2017-04-15  33.871549 -118.396053
# 74108  2012-01-05                t  2017-09-10  40.706749  -73.942377
# 74109  2017-09-17                t         NaN  40.738535  -74.000157
# 74110  2012-11-26                f  2017-04-30  33.761096 -118.192409
# 74111         NaN              NaN         NaN        NaN         NaN
#
#                                              name  neighbourhood  \
# 74107                Spacious Hermosa 2 BR on PCH  Hermosa Beach
# 74108  Modern 2 Bedroom Apartment in Williamsburg   Williamsburg
# 74109        Designer's Apartment in HEART of NYC   West Village
# 74110              Cozy Boat at Shoreline Village     Long Beach
# 74111                                         NaN            NaN
#
#        number_of_reviews  review_scores_rating  \
# 74107               16.0                  93.0
# 74108               43.0                  94.0
# 74109                0.0                   NaN
# 74110              205.0                  96.0
# 74111                NaN                   NaN
#
#                                            thumbnail_url  zipcode  bedrooms  \
# 74107  https://a0.muscache.com/im/pictures/2b86560b-a...    90254       2.0
# 74108  https://a0.muscache.com/im/pictures/7fbe448c-5...  11206.0       2.0
# 74109  https://a0.muscache.com/im/pictures/b3971b63-0...    10011       0.0
# 74110  https://a0.muscache.com/im/pictures/22968537/d...    90802       1.0
# 74111                                                NaN      NaN       NaN
#
#        beds
# 74107   4.0
# 74108   2.0
# 74109   2.0
# 74110   2.0
# 74111   NaN

# %%
df = df[:-1]

# %%
df.shape
# Out:
# (74111, 29)

# %%
df.dtypes
# Out:
# 14fc7c55076590dad3ef272ad3efff7c.csv    float64
# log_price                               float64
# property_type                            object
# room_type                                object
# amenities                                object
# accommodates                            float64
# bathrooms                               float64
# bed_type                                 object
# cancellation_policy                      object
# cleaning_fee                             object
# city                                     object
# description                              object
# first_review                             object
# host_has_profile_pic                     object
# host_identity_verified                   object
# host_response_rate                       object
# host_since                               object
# instant_bookable                         object
# last_review                              object
# latitude                                float64
# longitude                               float64
# name                                     object
# neighbourhood                            object
# number_of_reviews                       float64
# review_scores_rating                    float64
# thumbnail_url                            object
# zipcode                                  object
# bedrooms                                float64
# beds                                    float64
# dtype: object

# %%
missing_values = df.isnull().sum()
missing_values = missing_values[missing_values > 0]
missing_values
# Out:
# bathrooms                   200
# first_review              15864
# host_has_profile_pic        188
# host_identity_verified      188
# host_response_rate        18299
# host_since                  188
# last_review               15827
# neighbourhood              6872
# review_scores_rating      16722
# thumbnail_url              8216
# zipcode                     966
# bedrooms                     91
# beds                        131
# dtype: int64

# %%
df['14fc7c55076590dad3ef272ad3efff7c.csv'] = pd.to_numeric(df['14fc7c55076590dad3ef272ad3efff7c.csv'], errors='coerce', downcast='integer')
df.rename(columns={'14fc7c55076590dad3ef272ad3efff7c.csv': 'id'}, inplace=True)

# %%
unique_values_counts = {col: df[col].nunique() for col in df.columns}
unique_values_counts
# Out:
# {'id': 74111,
#  'log_price': 767,
#  'property_type': 35,
#  'room_type': 3,
#  'amenities': 67122,
#  'accommodates': 16,
#  'bathrooms': 17,
#  'bed_type': 5,
#  'cancellation_policy': 5,
#  'cleaning_fee': 2,
#  'city': 6,
#  'description': 73479,
#  'first_review': 2554,
#  'host_has_profile_pic': 2,
#  'host_identity_verified': 2,
#  'host_response_rate': 80,
#  'host_since': 3087,
#  'instant_bookable': 2,
#  'last_review': 1371,
#  'latitude': 74111,
#  'longitude': 74111,
#  'name': 73359,
#  'neighbourhood': 619,
#  'number_of_reviews': 371,
#  'review_scores_rating': 54,
#  'thumbnail_url': 65883,
#  'zipcode': 769,
#  'bedrooms': 11,
#  'beds': 18}

# %%
df_encoded = pd.get_dummies(df, columns=[
    'property_type', 'room_type', 'bed_type', 'cancellation_policy',
     'city','cleaning_fee','host_has_profile_pic', 'host_identity_verified',
     'instant_bookable'
     ])

# %%
df_encoded
# Out:
#              id  log_price                                          amenities  \
# 0       6901257   5.010635  {"Wireless Internet","Air conditioning",Kitche...
# 1       6304928   5.129899  {"Wireless Internet","Air conditioning",Kitche...
# 2       7919400   4.976734  {TV,"Cable TV","Wireless Internet","Air condit...
# 3      13418779   6.620073  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 4       3808709   4.744932  {TV,Internet,"Wireless Internet","Air conditio...
# ...         ...        ...                                                ...
# 74106  14549287   4.605170                                                 {}
# 74107  13281809   5.043425  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 74108  18688039   5.220356  {TV,Internet,"Wireless Internet","Air conditio...
# 74109  17045948   5.273000  {TV,"Wireless Internet","Air conditioning",Kit...
# 74110   3534845   4.852030  {TV,Internet,"Wireless Internet",Kitchen,"Free...
#
#        accommodates  bathrooms  \
# 0               3.0        1.0
# 1               7.0        1.0
# 2               5.0        1.0
# 3               4.0        1.0
# 4               2.0        1.0
# ...             ...        ...
# 74106           1.0        1.0
# 74107           4.0        2.0
# 74108           5.0        1.0
# 74109           2.0        1.0
# 74110           4.0        1.0
#
#                                              description first_review  \
# 0      Beautiful, sunlit brownstone 1-bedroom in the ...   2016-06-18
# 1      Enjoy travelling during your stay in Manhattan...   2017-08-05
# 2      The Oasis comes complete with a full backyard ...   2017-04-30
# 3      This light-filled home-away-from-home is super...          NaN
# 4      Cool, cozy, and comfortable studio located in ...   2015-05-12
# ...                                                  ...          ...
# 74106                          one room in bushwick apt           NaN
# 74107  Located on the Pacific Coast Highway, this apa...   2016-08-15
# 74108  A modern apartment located in East Williamsbur...   2015-01-03
# 74109  Fully renovated, designer's studio located in ...          NaN
# 74110  You will stay-aboard the Island Trader at one ...   2013-09-05
#
#       host_response_rate  host_since last_review   latitude   longitude  \
# 0                    NaN  2012-03-26  2016-07-18  40.696524  -73.991617
# 1                   100%  2017-06-19  2017-09-23  40.766115  -73.989040
# 2                   100%  2016-10-25  2017-09-14  40.808110  -73.943756
# 3                    NaN  2015-04-19         NaN  37.772004 -122.431619
# 4                   100%  2015-03-01  2017-01-22  38.925627  -77.034596
# ...                  ...         ...         ...        ...         ...
# 74106                NaN  2013-03-24         NaN  40.709025  -73.939405
# 74107               100%  2016-05-03  2017-04-15  33.871549 -118.396053
# 74108               100%  2012-01-05  2017-09-10  40.706749  -73.942377
# 74109               100%  2017-09-17         NaN  40.738535  -74.000157
# 74110               100%  2012-11-26  2017-04-30  33.761096 -118.192409
#
#                                              name     neighbourhood  \
# 0                  Beautiful brownstone 1-bedroom  Brooklyn Heights
# 1        Superb 3BR Apt Located Near Times Square    Hell's Kitchen
# 2                                The Garden Oasis            Harlem
# 3              Beautiful Flat in the Heart of SF!      Lower Haight
# 4                      Great studio in midtown DC  Columbia Heights
# ...                                           ...               ...
# 74106                           one room bushwick      Williamsburg
# 74107                Spacious Hermosa 2 BR on PCH     Hermosa Beach
# 74108  Modern 2 Bedroom Apartment in Williamsburg      Williamsburg
# 74109        Designer's Apartment in HEART of NYC      West Village
# 74110              Cozy Boat at Shoreline Village        Long Beach
#
#        number_of_reviews  review_scores_rating  \
# 0                    2.0                 100.0
# 1                    6.0                  93.0
# 2                   10.0                  92.0
# 3                    0.0                   NaN
# 4                    4.0                  40.0
# ...                  ...                   ...
# 74106                0.0                   NaN
# 74107               16.0                  93.0
# 74108               43.0                  94.0
# 74109                0.0                   NaN
# 74110              205.0                  96.0
#
#                                            thumbnail_url  zipcode  bedrooms  \
# 0      https://a0.muscache.com/im/pictures/6d7cbbf7-c...    11201       1.0
# 1      https://a0.muscache.com/im/pictures/348a55fe-4...    10019       3.0
# 2      https://a0.muscache.com/im/pictures/6fae5362-9...    10027       1.0
# 3      https://a0.muscache.com/im/pictures/72208dad-9...  94117.0       2.0
# 4                                                    NaN    20009       0.0
# ...                                                  ...      ...       ...
# 74106  https://a0.muscache.com/im/pictures/55162426/6...  11206.0       1.0
# 74107  https://a0.muscache.com/im/pictures/2b86560b-a...    90254       2.0
# 74108  https://a0.muscache.com/im/pictures/7fbe448c-5...  11206.0       2.0
# 74109  https://a0.muscache.com/im/pictures/b3971b63-0...    10011       0.0
# 74110  https://a0.muscache.com/im/pictures/22968537/d...    90802       1.0
#
#        beds  property_type_Apartment  property_type_Bed & Breakfast  \
# 0       1.0                     True                          False
# 1       3.0                     True                          False
# 2       3.0                     True                          False
# 3       2.0                    False                          False
# 4       1.0                     True                          False
# ...     ...                      ...                            ...
# 74106   1.0                     True                          False
# 74107   4.0                     True                          False
# 74108   2.0                     True                          False
# 74109   2.0                     True                          False
# 74110   2.0                    False                          False
#
#        property_type_Boat  property_type_Boutique hotel  \
# 0                   False                         False
# 1                   False                         False
# 2                   False                         False
# 3                   False                         False
# 4                   False                         False
# ...                   ...                           ...
# 74106               False                         False
# 74107               False                         False
# 74108               False                         False
# 74109               False                         False
# 74110                True                         False
#
#        property_type_Bungalow  property_type_Cabin  property_type_Camper/RV  \
# 0                       False                False                    False
# 1                       False                False                    False
# 2                       False                False                    False
# 3                       False                False                    False
# 4                       False                False                    False
# ...                       ...                  ...                      ...
# 74106                   False                False                    False
# 74107                   False                False                    False
# 74108                   False                False                    False
# 74109                   False                False                    False
# 74110                   False                False                    False
#
#        property_type_Casa particular  property_type_Castle  \
# 0                              False                 False
# 1                              False                 False
# 2                              False                 False
# 3                              False                 False
# 4                              False                 False
# ...                              ...                   ...
# 74106                          False                 False
# 74107                          False                 False
# 74108                          False                 False
# 74109                          False                 False
# 74110                          False                 False
#
#        property_type_Cave  property_type_Chalet  property_type_Condominium  \
# 0                   False                 False                      False
# 1                   False                 False                      False
# 2                   False                 False                      False
# 3                   False                 False                      False
# 4                   False                 False                      False
# ...                   ...                   ...                        ...
# 74106               False                 False                      False
# 74107               False                 False                      False
# 74108               False                 False                      False
# 74109               False                 False                      False
# 74110               False                 False                      False
#
#        property_type_Dorm  property_type_Earth House  \
# 0                   False                      False
# 1                   False                      False
# 2                   False                      False
# 3                   False                      False
# 4                   False                      False
# ...                   ...                        ...
# 74106               False                      False
# 74107               False                      False
# 74108               False                      False
# 74109               False                      False
# 74110               False                      False
#
#        property_type_Guest suite  property_type_Guesthouse  \
# 0                          False                     False
# 1                          False                     False
# 2                          False                     False
# 3                          False                     False
# 4                          False                     False
# ...                          ...                       ...
# 74106                      False                     False
# 74107                      False                     False
# 74108                      False                     False
# 74109                      False                     False
# 74110                      False                     False
#
#        property_type_Hostel  property_type_House  property_type_Hut  \
# 0                     False                False              False
# 1                     False                False              False
# 2                     False                False              False
# 3                     False                 True              False
# 4                     False                False              False
# ...                     ...                  ...                ...
# 74106                 False                False              False
# 74107                 False                False              False
# 74108                 False                False              False
# 74109                 False                False              False
# 74110                 False                False              False
#
#        property_type_In-law  property_type_Island  property_type_Lighthouse  \
# 0                     False                 False                     False
# 1                     False                 False                     False
# 2                     False                 False                     False
# 3                     False                 False                     False
# 4                     False                 False                     False
# ...                     ...                   ...                       ...
# 74106                 False                 False                     False
# 74107                 False                 False                     False
# 74108                 False                 False                     False
# 74109                 False                 False                     False
# 74110                 False                 False                     False
#
#        property_type_Loft  property_type_Other  property_type_Parking Space  \
# 0                   False                False                        False
# 1                   False                False                        False
# 2                   False                False                        False
# 3                   False                False                        False
# 4                   False                False                        False
# ...                   ...                  ...                          ...
# 74106               False                False                        False
# 74107               False                False                        False
# 74108               False                False                        False
# 74109               False                False                        False
# 74110               False                False                        False
#
#        property_type_Serviced apartment  property_type_Tent  \
# 0                                 False               False
# 1                                 False               False
# 2                                 False               False
# 3                                 False               False
# 4                                 False               False
# ...                                 ...                 ...
# 74106                             False               False
# 74107                             False               False
# 74108                             False               False
# 74109                             False               False
# 74110                             False               False
#
#        property_type_Timeshare  property_type_Tipi  property_type_Townhouse  \
# 0                        False               False                    False
# 1                        False               False                    False
# 2                        False               False                    False
# 3                        False               False                    False
# 4                        False               False                    False
# ...                        ...                 ...                      ...
# 74106                    False               False                    False
# 74107                    False               False                    False
# 74108                    False               False                    False
# 74109                    False               False                    False
# 74110                    False               False                    False
#
#        property_type_Train  property_type_Treehouse  \
# 0                    False                    False
# 1                    False                    False
# 2                    False                    False
# 3                    False                    False
# 4                    False                    False
# ...                    ...                      ...
# 74106                False                    False
# 74107                False                    False
# 74108                False                    False
# 74109                False                    False
# 74110                False                    False
#
#        property_type_Vacation home  property_type_Villa  property_type_Yurt  \
# 0                            False                False               False
# 1                            False                False               False
# 2                            False                False               False
# 3                            False                False               False
# 4                            False                False               False
# ...                            ...                  ...                 ...
# 74106                        False                False               False
# 74107                        False                False               False
# 74108                        False                False               False
# 74109                        False                False               False
# 74110                        False                False               False
#
#        room_type_Entire home/apt  room_type_Private room  \
# 0                           True                   False
# 1                           True                   False
# 2                           True                   False
# 3                           True                   False
# 4                           True                   False
# ...                          ...                     ...
# 74106                      False                    True
# 74107                       True                   False
# 74108                       True                   False
# 74109                       True                   False
# 74110                       True                   False
#
#        room_type_Shared room  bed_type_Airbed  bed_type_Couch  bed_type_Futon  \
# 0                      False            False           False           False
# 1                      False            False           False           False
# 2                      False            False           False           False
# 3                      False            False           False           False
# 4                      False            False           False           False
# ...                      ...              ...             ...             ...
# 74106                  False            False           False           False
# 74107                  False            False           False           False
# 74108                  False            False           False           False
# 74109                  False            False           False           False
# 74110                  False            False           False           False
#
#        bed_type_Pull-out Sofa  bed_type_Real Bed  \
# 0                       False               True
# 1                       False               True
# 2                       False               True
# 3                       False               True
# 4                       False               True
# ...                       ...                ...
# 74106                   False               True
# 74107                   False               True
# 74108                   False               True
# 74109                   False               True
# 74110                   False               True
#
#        cancellation_policy_flexible  cancellation_policy_moderate  \
# 0                             False                         False
# 1                             False                         False
# 2                             False                          True
# 3                              True                         False
# 4                             False                          True
# ...                             ...                           ...
# 74106                          True                         False
# 74107                         False                          True
# 74108                         False                          True
# 74109                         False                         False
# 74110                         False                          True
#
#        cancellation_policy_strict  cancellation_policy_super_strict_30  \
# 0                            True                                False
# 1                            True                                False
# 2                           False                                False
# 3                           False                                False
# 4                           False                                False
# ...                           ...                                  ...
# 74106                       False                                False
# 74107                       False                                False
# 74108                       False                                False
# 74109                        True                                False
# 74110                       False                                False
#
#        cancellation_policy_super_strict_60  city_Boston  city_Chicago  \
# 0                                    False        False         False
# 1                                    False        False         False
# 2                                    False        False         False
# 3                                    False        False         False
# 4                                    False        False         False
# ...                                    ...          ...           ...
# 74106                                False        False         False
# 74107                                False        False         False
# 74108                                False        False         False
# 74109                                False        False         False
# 74110                                False        False         False
#
#        city_DC  city_LA  city_NYC  city_SF  cleaning_fee_False  \
# 0        False    False      True    False               False
# 1        False    False      True    False               False
# 2        False    False      True    False               False
# 3        False    False     False     True               False
# 4         True    False     False    False               False
# ...        ...      ...       ...      ...                 ...
# 74106    False    False      True    False                True
# 74107    False     True     False    False               False
# 74108    False    False      True    False               False
# 74109    False    False      True    False               False
# 74110    False     True     False    False                True
#
#        cleaning_fee_True  host_has_profile_pic_f  host_has_profile_pic_t  \
# 0                   True                   False                    True
# 1                   True                   False                    True
# 2                   True                   False                    True
# 3                   True                   False                    True
# 4                   True                   False                    True
# ...                  ...                     ...                     ...
# 74106              False                   False                    True
# 74107               True                   False                    True
# 74108               True                   False                    True
# 74109               True                   False                    True
# 74110              False                   False                    True
#
#        host_identity_verified_f  host_identity_verified_t  instant_bookable_f  \
# 0                         False                      True                True
# 1                          True                     False               False
# 2                         False                      True               False
# 3                         False                      True                True
# 4                         False                      True               False
# ...                         ...                       ...                 ...
# 74106                     False                      True                True
# 74107                      True                     False                True
# 74108                     False                      True               False
# 74109                      True                     False               False
# 74110                     False                      True                True
#
#        instant_bookable_t
# 0                   False
# 1                    True
# 2                    True
# 3                   False
# 4                    True
# ...                   ...
# 74106               False
# 74107               False
# 74108                True
# 74109                True
# 74110               False
#
# [74111 rows x 82 columns]

# %%
df.head()
# Out:
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...           3.0        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...           7.0        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...           5.0        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...           4.0        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...           2.0        1.0
#
#    bed_type cancellation_policy cleaning_fee city  \
# 0  Real Bed              strict         True  NYC
# 1  Real Bed              strict         True  NYC
# 2  Real Bed            moderate         True  NYC
# 3  Real Bed            flexible         True   SF
# 4  Real Bed            moderate         True   DC
#
#                                          description first_review  \
# 0  Beautiful, sunlit brownstone 1-bedroom in the ...   2016-06-18
# 1  Enjoy travelling during your stay in Manhattan...   2017-08-05
# 2  The Oasis comes complete with a full backyard ...   2017-04-30
# 3  This light-filled home-away-from-home is super...          NaN
# 4  Cool, cozy, and comfortable studio located in ...   2015-05-12
#
#   host_has_profile_pic host_identity_verified host_response_rate  host_since  \
# 0                    t                      t                NaN  2012-03-26
# 1                    t                      f               100%  2017-06-19
# 2                    t                      t               100%  2016-10-25
# 3                    t                      t                NaN  2015-04-19
# 4                    t                      t               100%  2015-03-01
#
#   instant_bookable last_review   latitude   longitude  \
# 0                f  2016-07-18  40.696524  -73.991617
# 1                t  2017-09-23  40.766115  -73.989040
# 2                t  2017-09-14  40.808110  -73.943756
# 3                f         NaN  37.772004 -122.431619
# 4                t  2017-01-22  38.925627  -77.034596
#
#                                        name     neighbourhood  \
# 0            Beautiful brownstone 1-bedroom  Brooklyn Heights
# 1  Superb 3BR Apt Located Near Times Square    Hell's Kitchen
# 2                          The Garden Oasis            Harlem
# 3        Beautiful Flat in the Heart of SF!      Lower Haight
# 4                Great studio in midtown DC  Columbia Heights
#
#    number_of_reviews  review_scores_rating  \
# 0                2.0                 100.0
# 1                6.0                  93.0
# 2               10.0                  92.0
# 3                0.0                   NaN
# 4                4.0                  40.0
#
#                                        thumbnail_url  zipcode  bedrooms  beds
# 0  https://a0.muscache.com/im/pictures/6d7cbbf7-c...    11201       1.0   1.0
# 1  https://a0.muscache.com/im/pictures/348a55fe-4...    10019       3.0   3.0
# 2  https://a0.muscache.com/im/pictures/6fae5362-9...    10027       1.0   3.0
# 3  https://a0.muscache.com/im/pictures/72208dad-9...  94117.0       2.0   2.0
# 4                                                NaN    20009       0.0   1.0

# %%
df_encoded.shape
# Out:
# (74111, 82)

# %%
missing_values = df_encoded.isnull().sum()
missing_values = missing_values[missing_values > 0]
missing_values
# Out:
# bathrooms                 200
# first_review            15864
# host_response_rate      18299
# host_since                188
# last_review             15827
# neighbourhood            6872
# review_scores_rating    16722
# thumbnail_url            8216
# zipcode                   966
# bedrooms                   91
# beds                      131
# dtype: int64

# %% [markdown]
# We remove the column with an excessively large number of categories, making it unsuitable for one-hot encoding.
#
# Also remove the observation that containing a small number of missing values.

# %%
df_encoded.drop(['thumbnail_url', 'zipcode','neighbourhood','first_review', 'last_review'], axis=1, inplace=True)
df_encoded.dropna(subset=['host_since'], inplace=True)

# %%
df_melted = df.melt(value_vars=['bathrooms', 'bedrooms', 'beds'], var_name='Variable', value_name='Value')

# Drawing the boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Variable', y='Value', data=df_melted)
plt.title('Distribution of Bathrooms, Bedrooms, and Beds')
plt.show()
# Out:
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# The boxplot reveals the presence of outliers, makes the median a more reliable measure than the mean for imputing missing values.
#
# Then filling missing values in each column with the median of that column grouped by the 'accommodates' category.

# %%
for col in ['bathrooms', 'bedrooms', 'beds']:
    df_encoded[col] = df.groupby('accommodates')[col].transform(lambda x: x.fillna(x.median()))

# %%
df_encoded
# Out:
#              id  log_price                                          amenities  \
# 0       6901257   5.010635  {"Wireless Internet","Air conditioning",Kitche...
# 1       6304928   5.129899  {"Wireless Internet","Air conditioning",Kitche...
# 2       7919400   4.976734  {TV,"Cable TV","Wireless Internet","Air condit...
# 3      13418779   6.620073  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 4       3808709   4.744932  {TV,Internet,"Wireless Internet","Air conditio...
# ...         ...        ...                                                ...
# 74106  14549287   4.605170                                                 {}
# 74107  13281809   5.043425  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 74108  18688039   5.220356  {TV,Internet,"Wireless Internet","Air conditio...
# 74109  17045948   5.273000  {TV,"Wireless Internet","Air conditioning",Kit...
# 74110   3534845   4.852030  {TV,Internet,"Wireless Internet",Kitchen,"Free...
#
#        accommodates  bathrooms  \
# 0               3.0        1.0
# 1               7.0        1.0
# 2               5.0        1.0
# 3               4.0        1.0
# 4               2.0        1.0
# ...             ...        ...
# 74106           1.0        1.0
# 74107           4.0        2.0
# 74108           5.0        1.0
# 74109           2.0        1.0
# 74110           4.0        1.0
#
#                                              description host_response_rate  \
# 0      Beautiful, sunlit brownstone 1-bedroom in the ...                NaN
# 1      Enjoy travelling during your stay in Manhattan...               100%
# 2      The Oasis comes complete with a full backyard ...               100%
# 3      This light-filled home-away-from-home is super...                NaN
# 4      Cool, cozy, and comfortable studio located in ...               100%
# ...                                                  ...                ...
# 74106                          one room in bushwick apt                 NaN
# 74107  Located on the Pacific Coast Highway, this apa...               100%
# 74108  A modern apartment located in East Williamsbur...               100%
# 74109  Fully renovated, designer's studio located in ...               100%
# 74110  You will stay-aboard the Island Trader at one ...               100%
#
#        host_since   latitude   longitude  \
# 0      2012-03-26  40.696524  -73.991617
# 1      2017-06-19  40.766115  -73.989040
# 2      2016-10-25  40.808110  -73.943756
# 3      2015-04-19  37.772004 -122.431619
# 4      2015-03-01  38.925627  -77.034596
# ...           ...        ...         ...
# 74106  2013-03-24  40.709025  -73.939405
# 74107  2016-05-03  33.871549 -118.396053
# 74108  2012-01-05  40.706749  -73.942377
# 74109  2017-09-17  40.738535  -74.000157
# 74110  2012-11-26  33.761096 -118.192409
#
#                                              name  number_of_reviews  \
# 0                  Beautiful brownstone 1-bedroom                2.0
# 1        Superb 3BR Apt Located Near Times Square                6.0
# 2                                The Garden Oasis               10.0
# 3              Beautiful Flat in the Heart of SF!                0.0
# 4                      Great studio in midtown DC                4.0
# ...                                           ...                ...
# 74106                           one room bushwick                0.0
# 74107                Spacious Hermosa 2 BR on PCH               16.0
# 74108  Modern 2 Bedroom Apartment in Williamsburg               43.0
# 74109        Designer's Apartment in HEART of NYC                0.0
# 74110              Cozy Boat at Shoreline Village              205.0
#
#        review_scores_rating  bedrooms  beds  property_type_Apartment  \
# 0                     100.0       1.0   1.0                     True
# 1                      93.0       3.0   3.0                     True
# 2                      92.0       1.0   3.0                     True
# 3                       NaN       2.0   2.0                    False
# 4                      40.0       0.0   1.0                     True
# ...                     ...       ...   ...                      ...
# 74106                   NaN       1.0   1.0                     True
# 74107                  93.0       2.0   4.0                     True
# 74108                  94.0       2.0   2.0                     True
# 74109                   NaN       0.0   2.0                     True
# 74110                  96.0       1.0   2.0                    False
#
#        property_type_Bed & Breakfast  property_type_Boat  \
# 0                              False               False
# 1                              False               False
# 2                              False               False
# 3                              False               False
# 4                              False               False
# ...                              ...                 ...
# 74106                          False               False
# 74107                          False               False
# 74108                          False               False
# 74109                          False               False
# 74110                          False                True
#
#        property_type_Boutique hotel  property_type_Bungalow  \
# 0                             False                   False
# 1                             False                   False
# 2                             False                   False
# 3                             False                   False
# 4                             False                   False
# ...                             ...                     ...
# 74106                         False                   False
# 74107                         False                   False
# 74108                         False                   False
# 74109                         False                   False
# 74110                         False                   False
#
#        property_type_Cabin  property_type_Camper/RV  \
# 0                    False                    False
# 1                    False                    False
# 2                    False                    False
# 3                    False                    False
# 4                    False                    False
# ...                    ...                      ...
# 74106                False                    False
# 74107                False                    False
# 74108                False                    False
# 74109                False                    False
# 74110                False                    False
#
#        property_type_Casa particular  property_type_Castle  \
# 0                              False                 False
# 1                              False                 False
# 2                              False                 False
# 3                              False                 False
# 4                              False                 False
# ...                              ...                   ...
# 74106                          False                 False
# 74107                          False                 False
# 74108                          False                 False
# 74109                          False                 False
# 74110                          False                 False
#
#        property_type_Cave  property_type_Chalet  property_type_Condominium  \
# 0                   False                 False                      False
# 1                   False                 False                      False
# 2                   False                 False                      False
# 3                   False                 False                      False
# 4                   False                 False                      False
# ...                   ...                   ...                        ...
# 74106               False                 False                      False
# 74107               False                 False                      False
# 74108               False                 False                      False
# 74109               False                 False                      False
# 74110               False                 False                      False
#
#        property_type_Dorm  property_type_Earth House  \
# 0                   False                      False
# 1                   False                      False
# 2                   False                      False
# 3                   False                      False
# 4                   False                      False
# ...                   ...                        ...
# 74106               False                      False
# 74107               False                      False
# 74108               False                      False
# 74109               False                      False
# 74110               False                      False
#
#        property_type_Guest suite  property_type_Guesthouse  \
# 0                          False                     False
# 1                          False                     False
# 2                          False                     False
# 3                          False                     False
# 4                          False                     False
# ...                          ...                       ...
# 74106                      False                     False
# 74107                      False                     False
# 74108                      False                     False
# 74109                      False                     False
# 74110                      False                     False
#
#        property_type_Hostel  property_type_House  property_type_Hut  \
# 0                     False                False              False
# 1                     False                False              False
# 2                     False                False              False
# 3                     False                 True              False
# 4                     False                False              False
# ...                     ...                  ...                ...
# 74106                 False                False              False
# 74107                 False                False              False
# 74108                 False                False              False
# 74109                 False                False              False
# 74110                 False                False              False
#
#        property_type_In-law  property_type_Island  property_type_Lighthouse  \
# 0                     False                 False                     False
# 1                     False                 False                     False
# 2                     False                 False                     False
# 3                     False                 False                     False
# 4                     False                 False                     False
# ...                     ...                   ...                       ...
# 74106                 False                 False                     False
# 74107                 False                 False                     False
# 74108                 False                 False                     False
# 74109                 False                 False                     False
# 74110                 False                 False                     False
#
#        property_type_Loft  property_type_Other  property_type_Parking Space  \
# 0                   False                False                        False
# 1                   False                False                        False
# 2                   False                False                        False
# 3                   False                False                        False
# 4                   False                False                        False
# ...                   ...                  ...                          ...
# 74106               False                False                        False
# 74107               False                False                        False
# 74108               False                False                        False
# 74109               False                False                        False
# 74110               False                False                        False
#
#        property_type_Serviced apartment  property_type_Tent  \
# 0                                 False               False
# 1                                 False               False
# 2                                 False               False
# 3                                 False               False
# 4                                 False               False
# ...                                 ...                 ...
# 74106                             False               False
# 74107                             False               False
# 74108                             False               False
# 74109                             False               False
# 74110                             False               False
#
#        property_type_Timeshare  property_type_Tipi  property_type_Townhouse  \
# 0                        False               False                    False
# 1                        False               False                    False
# 2                        False               False                    False
# 3                        False               False                    False
# 4                        False               False                    False
# ...                        ...                 ...                      ...
# 74106                    False               False                    False
# 74107                    False               False                    False
# 74108                    False               False                    False
# 74109                    False               False                    False
# 74110                    False               False                    False
#
#        property_type_Train  property_type_Treehouse  \
# 0                    False                    False
# 1                    False                    False
# 2                    False                    False
# 3                    False                    False
# 4                    False                    False
# ...                    ...                      ...
# 74106                False                    False
# 74107                False                    False
# 74108                False                    False
# 74109                False                    False
# 74110                False                    False
#
#        property_type_Vacation home  property_type_Villa  property_type_Yurt  \
# 0                            False                False               False
# 1                            False                False               False
# 2                            False                False               False
# 3                            False                False               False
# 4                            False                False               False
# ...                            ...                  ...                 ...
# 74106                        False                False               False
# 74107                        False                False               False
# 74108                        False                False               False
# 74109                        False                False               False
# 74110                        False                False               False
#
#        room_type_Entire home/apt  room_type_Private room  \
# 0                           True                   False
# 1                           True                   False
# 2                           True                   False
# 3                           True                   False
# 4                           True                   False
# ...                          ...                     ...
# 74106                      False                    True
# 74107                       True                   False
# 74108                       True                   False
# 74109                       True                   False
# 74110                       True                   False
#
#        room_type_Shared room  bed_type_Airbed  bed_type_Couch  bed_type_Futon  \
# 0                      False            False           False           False
# 1                      False            False           False           False
# 2                      False            False           False           False
# 3                      False            False           False           False
# 4                      False            False           False           False
# ...                      ...              ...             ...             ...
# 74106                  False            False           False           False
# 74107                  False            False           False           False
# 74108                  False            False           False           False
# 74109                  False            False           False           False
# 74110                  False            False           False           False
#
#        bed_type_Pull-out Sofa  bed_type_Real Bed  \
# 0                       False               True
# 1                       False               True
# 2                       False               True
# 3                       False               True
# 4                       False               True
# ...                       ...                ...
# 74106                   False               True
# 74107                   False               True
# 74108                   False               True
# 74109                   False               True
# 74110                   False               True
#
#        cancellation_policy_flexible  cancellation_policy_moderate  \
# 0                             False                         False
# 1                             False                         False
# 2                             False                          True
# 3                              True                         False
# 4                             False                          True
# ...                             ...                           ...
# 74106                          True                         False
# 74107                         False                          True
# 74108                         False                          True
# 74109                         False                         False
# 74110                         False                          True
#
#        cancellation_policy_strict  cancellation_policy_super_strict_30  \
# 0                            True                                False
# 1                            True                                False
# 2                           False                                False
# 3                           False                                False
# 4                           False                                False
# ...                           ...                                  ...
# 74106                       False                                False
# 74107                       False                                False
# 74108                       False                                False
# 74109                        True                                False
# 74110                       False                                False
#
#        cancellation_policy_super_strict_60  city_Boston  city_Chicago  \
# 0                                    False        False         False
# 1                                    False        False         False
# 2                                    False        False         False
# 3                                    False        False         False
# 4                                    False        False         False
# ...                                    ...          ...           ...
# 74106                                False        False         False
# 74107                                False        False         False
# 74108                                False        False         False
# 74109                                False        False         False
# 74110                                False        False         False
#
#        city_DC  city_LA  city_NYC  city_SF  cleaning_fee_False  \
# 0        False    False      True    False               False
# 1        False    False      True    False               False
# 2        False    False      True    False               False
# 3        False    False     False     True               False
# 4         True    False     False    False               False
# ...        ...      ...       ...      ...                 ...
# 74106    False    False      True    False                True
# 74107    False     True     False    False               False
# 74108    False    False      True    False               False
# 74109    False    False      True    False               False
# 74110    False     True     False    False                True
#
#        cleaning_fee_True  host_has_profile_pic_f  host_has_profile_pic_t  \
# 0                   True                   False                    True
# 1                   True                   False                    True
# 2                   True                   False                    True
# 3                   True                   False                    True
# 4                   True                   False                    True
# ...                  ...                     ...                     ...
# 74106              False                   False                    True
# 74107               True                   False                    True
# 74108               True                   False                    True
# 74109               True                   False                    True
# 74110              False                   False                    True
#
#        host_identity_verified_f  host_identity_verified_t  instant_bookable_f  \
# 0                         False                      True                True
# 1                          True                     False               False
# 2                         False                      True               False
# 3                         False                      True                True
# 4                         False                      True               False
# ...                         ...                       ...                 ...
# 74106                     False                      True                True
# 74107                      True                     False                True
# 74108                     False                      True               False
# 74109                      True                     False               False
# 74110                     False                      True                True
#
#        instant_bookable_t
# 0                   False
# 1                    True
# 2                    True
# 3                   False
# 4                    True
# ...                   ...
# 74106               False
# 74107               False
# 74108                True
# 74109                True
# 74110               False
#
# [73923 rows x 77 columns]

# %%
df.shape
# Out:
# (74111, 29)

# %%
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.histplot(df_encoded['host_response_rate'], kde=True)
plt.title('Distribution of Host Response Rate')

plt.subplot(1, 2, 2)
sns.histplot(df_encoded['review_scores_rating'], kde=True)
plt.title('Distribution of Review Scores Rating')

plt.tight_layout()
plt.show()
# Out:
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Impute missing 'host_response_rate' with the median
df_encoded['host_response_rate'] = df_encoded['host_response_rate'].str.rstrip('%').astype(float)
df_encoded['host_response_rate'].fillna(df_encoded['host_response_rate'].median(), inplace=True)

# Impute missing 'review_scores_rating' with the median
df_encoded['review_scores_rating'].fillna(df_encoded['review_scores_rating'].median(), inplace=True)

# %%
missing_values = df_encoded.isnull().sum()
missing_values = missing_values[missing_values > 0]
missing_values
# Out:
# Series([], dtype: int64)

# %%
df_encoded
# Out:
#              id  log_price                                          amenities  \
# 0       6901257   5.010635  {"Wireless Internet","Air conditioning",Kitche...
# 1       6304928   5.129899  {"Wireless Internet","Air conditioning",Kitche...
# 2       7919400   4.976734  {TV,"Cable TV","Wireless Internet","Air condit...
# 3      13418779   6.620073  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 4       3808709   4.744932  {TV,Internet,"Wireless Internet","Air conditio...
# ...         ...        ...                                                ...
# 74106  14549287   4.605170                                                 {}
# 74107  13281809   5.043425  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 74108  18688039   5.220356  {TV,Internet,"Wireless Internet","Air conditio...
# 74109  17045948   5.273000  {TV,"Wireless Internet","Air conditioning",Kit...
# 74110   3534845   4.852030  {TV,Internet,"Wireless Internet",Kitchen,"Free...
#
#        accommodates  bathrooms  \
# 0               3.0        1.0
# 1               7.0        1.0
# 2               5.0        1.0
# 3               4.0        1.0
# 4               2.0        1.0
# ...             ...        ...
# 74106           1.0        1.0
# 74107           4.0        2.0
# 74108           5.0        1.0
# 74109           2.0        1.0
# 74110           4.0        1.0
#
#                                              description  host_response_rate  \
# 0      Beautiful, sunlit brownstone 1-bedroom in the ...               100.0
# 1      Enjoy travelling during your stay in Manhattan...               100.0
# 2      The Oasis comes complete with a full backyard ...               100.0
# 3      This light-filled home-away-from-home is super...               100.0
# 4      Cool, cozy, and comfortable studio located in ...               100.0
# ...                                                  ...                 ...
# 74106                          one room in bushwick apt                100.0
# 74107  Located on the Pacific Coast Highway, this apa...               100.0
# 74108  A modern apartment located in East Williamsbur...               100.0
# 74109  Fully renovated, designer's studio located in ...               100.0
# 74110  You will stay-aboard the Island Trader at one ...               100.0
#
#        host_since   latitude   longitude  \
# 0      2012-03-26  40.696524  -73.991617
# 1      2017-06-19  40.766115  -73.989040
# 2      2016-10-25  40.808110  -73.943756
# 3      2015-04-19  37.772004 -122.431619
# 4      2015-03-01  38.925627  -77.034596
# ...           ...        ...         ...
# 74106  2013-03-24  40.709025  -73.939405
# 74107  2016-05-03  33.871549 -118.396053
# 74108  2012-01-05  40.706749  -73.942377
# 74109  2017-09-17  40.738535  -74.000157
# 74110  2012-11-26  33.761096 -118.192409
#
#                                              name  number_of_reviews  \
# 0                  Beautiful brownstone 1-bedroom                2.0
# 1        Superb 3BR Apt Located Near Times Square                6.0
# 2                                The Garden Oasis               10.0
# 3              Beautiful Flat in the Heart of SF!                0.0
# 4                      Great studio in midtown DC                4.0
# ...                                           ...                ...
# 74106                           one room bushwick                0.0
# 74107                Spacious Hermosa 2 BR on PCH               16.0
# 74108  Modern 2 Bedroom Apartment in Williamsburg               43.0
# 74109        Designer's Apartment in HEART of NYC                0.0
# 74110              Cozy Boat at Shoreline Village              205.0
#
#        review_scores_rating  bedrooms  beds  property_type_Apartment  \
# 0                     100.0       1.0   1.0                     True
# 1                      93.0       3.0   3.0                     True
# 2                      92.0       1.0   3.0                     True
# 3                      96.0       2.0   2.0                    False
# 4                      40.0       0.0   1.0                     True
# ...                     ...       ...   ...                      ...
# 74106                  96.0       1.0   1.0                     True
# 74107                  93.0       2.0   4.0                     True
# 74108                  94.0       2.0   2.0                     True
# 74109                  96.0       0.0   2.0                     True
# 74110                  96.0       1.0   2.0                    False
#
#        property_type_Bed & Breakfast  property_type_Boat  \
# 0                              False               False
# 1                              False               False
# 2                              False               False
# 3                              False               False
# 4                              False               False
# ...                              ...                 ...
# 74106                          False               False
# 74107                          False               False
# 74108                          False               False
# 74109                          False               False
# 74110                          False                True
#
#        property_type_Boutique hotel  property_type_Bungalow  \
# 0                             False                   False
# 1                             False                   False
# 2                             False                   False
# 3                             False                   False
# 4                             False                   False
# ...                             ...                     ...
# 74106                         False                   False
# 74107                         False                   False
# 74108                         False                   False
# 74109                         False                   False
# 74110                         False                   False
#
#        property_type_Cabin  property_type_Camper/RV  \
# 0                    False                    False
# 1                    False                    False
# 2                    False                    False
# 3                    False                    False
# 4                    False                    False
# ...                    ...                      ...
# 74106                False                    False
# 74107                False                    False
# 74108                False                    False
# 74109                False                    False
# 74110                False                    False
#
#        property_type_Casa particular  property_type_Castle  \
# 0                              False                 False
# 1                              False                 False
# 2                              False                 False
# 3                              False                 False
# 4                              False                 False
# ...                              ...                   ...
# 74106                          False                 False
# 74107                          False                 False
# 74108                          False                 False
# 74109                          False                 False
# 74110                          False                 False
#
#        property_type_Cave  property_type_Chalet  property_type_Condominium  \
# 0                   False                 False                      False
# 1                   False                 False                      False
# 2                   False                 False                      False
# 3                   False                 False                      False
# 4                   False                 False                      False
# ...                   ...                   ...                        ...
# 74106               False                 False                      False
# 74107               False                 False                      False
# 74108               False                 False                      False
# 74109               False                 False                      False
# 74110               False                 False                      False
#
#        property_type_Dorm  property_type_Earth House  \
# 0                   False                      False
# 1                   False                      False
# 2                   False                      False
# 3                   False                      False
# 4                   False                      False
# ...                   ...                        ...
# 74106               False                      False
# 74107               False                      False
# 74108               False                      False
# 74109               False                      False
# 74110               False                      False
#
#        property_type_Guest suite  property_type_Guesthouse  \
# 0                          False                     False
# 1                          False                     False
# 2                          False                     False
# 3                          False                     False
# 4                          False                     False
# ...                          ...                       ...
# 74106                      False                     False
# 74107                      False                     False
# 74108                      False                     False
# 74109                      False                     False
# 74110                      False                     False
#
#        property_type_Hostel  property_type_House  property_type_Hut  \
# 0                     False                False              False
# 1                     False                False              False
# 2                     False                False              False
# 3                     False                 True              False
# 4                     False                False              False
# ...                     ...                  ...                ...
# 74106                 False                False              False
# 74107                 False                False              False
# 74108                 False                False              False
# 74109                 False                False              False
# 74110                 False                False              False
#
#        property_type_In-law  property_type_Island  property_type_Lighthouse  \
# 0                     False                 False                     False
# 1                     False                 False                     False
# 2                     False                 False                     False
# 3                     False                 False                     False
# 4                     False                 False                     False
# ...                     ...                   ...                       ...
# 74106                 False                 False                     False
# 74107                 False                 False                     False
# 74108                 False                 False                     False
# 74109                 False                 False                     False
# 74110                 False                 False                     False
#
#        property_type_Loft  property_type_Other  property_type_Parking Space  \
# 0                   False                False                        False
# 1                   False                False                        False
# 2                   False                False                        False
# 3                   False                False                        False
# 4                   False                False                        False
# ...                   ...                  ...                          ...
# 74106               False                False                        False
# 74107               False                False                        False
# 74108               False                False                        False
# 74109               False                False                        False
# 74110               False                False                        False
#
#        property_type_Serviced apartment  property_type_Tent  \
# 0                                 False               False
# 1                                 False               False
# 2                                 False               False
# 3                                 False               False
# 4                                 False               False
# ...                                 ...                 ...
# 74106                             False               False
# 74107                             False               False
# 74108                             False               False
# 74109                             False               False
# 74110                             False               False
#
#        property_type_Timeshare  property_type_Tipi  property_type_Townhouse  \
# 0                        False               False                    False
# 1                        False               False                    False
# 2                        False               False                    False
# 3                        False               False                    False
# 4                        False               False                    False
# ...                        ...                 ...                      ...
# 74106                    False               False                    False
# 74107                    False               False                    False
# 74108                    False               False                    False
# 74109                    False               False                    False
# 74110                    False               False                    False
#
#        property_type_Train  property_type_Treehouse  \
# 0                    False                    False
# 1                    False                    False
# 2                    False                    False
# 3                    False                    False
# 4                    False                    False
# ...                    ...                      ...
# 74106                False                    False
# 74107                False                    False
# 74108                False                    False
# 74109                False                    False
# 74110                False                    False
#
#        property_type_Vacation home  property_type_Villa  property_type_Yurt  \
# 0                            False                False               False
# 1                            False                False               False
# 2                            False                False               False
# 3                            False                False               False
# 4                            False                False               False
# ...                            ...                  ...                 ...
# 74106                        False                False               False
# 74107                        False                False               False
# 74108                        False                False               False
# 74109                        False                False               False
# 74110                        False                False               False
#
#        room_type_Entire home/apt  room_type_Private room  \
# 0                           True                   False
# 1                           True                   False
# 2                           True                   False
# 3                           True                   False
# 4                           True                   False
# ...                          ...                     ...
# 74106                      False                    True
# 74107                       True                   False
# 74108                       True                   False
# 74109                       True                   False
# 74110                       True                   False
#
#        room_type_Shared room  bed_type_Airbed  bed_type_Couch  bed_type_Futon  \
# 0                      False            False           False           False
# 1                      False            False           False           False
# 2                      False            False           False           False
# 3                      False            False           False           False
# 4                      False            False           False           False
# ...                      ...              ...             ...             ...
# 74106                  False            False           False           False
# 74107                  False            False           False           False
# 74108                  False            False           False           False
# 74109                  False            False           False           False
# 74110                  False            False           False           False
#
#        bed_type_Pull-out Sofa  bed_type_Real Bed  \
# 0                       False               True
# 1                       False               True
# 2                       False               True
# 3                       False               True
# 4                       False               True
# ...                       ...                ...
# 74106                   False               True
# 74107                   False               True
# 74108                   False               True
# 74109                   False               True
# 74110                   False               True
#
#        cancellation_policy_flexible  cancellation_policy_moderate  \
# 0                             False                         False
# 1                             False                         False
# 2                             False                          True
# 3                              True                         False
# 4                             False                          True
# ...                             ...                           ...
# 74106                          True                         False
# 74107                         False                          True
# 74108                         False                          True
# 74109                         False                         False
# 74110                         False                          True
#
#        cancellation_policy_strict  cancellation_policy_super_strict_30  \
# 0                            True                                False
# 1                            True                                False
# 2                           False                                False
# 3                           False                                False
# 4                           False                                False
# ...                           ...                                  ...
# 74106                       False                                False
# 74107                       False                                False
# 74108                       False                                False
# 74109                        True                                False
# 74110                       False                                False
#
#        cancellation_policy_super_strict_60  city_Boston  city_Chicago  \
# 0                                    False        False         False
# 1                                    False        False         False
# 2                                    False        False         False
# 3                                    False        False         False
# 4                                    False        False         False
# ...                                    ...          ...           ...
# 74106                                False        False         False
# 74107                                False        False         False
# 74108                                False        False         False
# 74109                                False        False         False
# 74110                                False        False         False
#
#        city_DC  city_LA  city_NYC  city_SF  cleaning_fee_False  \
# 0        False    False      True    False               False
# 1        False    False      True    False               False
# 2        False    False      True    False               False
# 3        False    False     False     True               False
# 4         True    False     False    False               False
# ...        ...      ...       ...      ...                 ...
# 74106    False    False      True    False                True
# 74107    False     True     False    False               False
# 74108    False    False      True    False               False
# 74109    False    False      True    False               False
# 74110    False     True     False    False                True
#
#        cleaning_fee_True  host_has_profile_pic_f  host_has_profile_pic_t  \
# 0                   True                   False                    True
# 1                   True                   False                    True
# 2                   True                   False                    True
# 3                   True                   False                    True
# 4                   True                   False                    True
# ...                  ...                     ...                     ...
# 74106              False                   False                    True
# 74107               True                   False                    True
# 74108               True                   False                    True
# 74109               True                   False                    True
# 74110              False                   False                    True
#
#        host_identity_verified_f  host_identity_verified_t  instant_bookable_f  \
# 0                         False                      True                True
# 1                          True                     False               False
# 2                         False                      True               False
# 3                         False                      True                True
# 4                         False                      True               False
# ...                         ...                       ...                 ...
# 74106                     False                      True                True
# 74107                      True                     False                True
# 74108                     False                      True               False
# 74109                      True                     False               False
# 74110                     False                      True                True
#
#        instant_bookable_t
# 0                   False
# 1                    True
# 2                    True
# 3                   False
# 4                    True
# ...                   ...
# 74106               False
# 74107               False
# 74108                True
# 74109                True
# 74110               False
#
# [73923 rows x 77 columns]

# %%
df_encoded.shape
# Out:
# (73923, 77)

# %% [markdown]
# ## Data Visulization

# %% [markdown]
# ### Histogram

# %%
# Plot the distribution of the Airbnb log prices
plt.figure(figsize=(10, 6))
plt.hist(df['log_price'], bins=50, color='green')
plt.title('Airbnb price distribution')
plt.xlabel('log_price')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Correlation matrix

# %%
# Select a subset of the dataframe for the Correlation matrix
numeric_features = ['log_price', 'accommodates', 'bathrooms', 'number_of_reviews', 'review_scores_rating', 'bedrooms', 'beds']
subset_df = df[numeric_features].dropna()
# Correlation matrix
corr_matrix = subset_df.corr()

# %% [markdown]
# ### Heatmap

# %%
# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %% [markdown]
# ### Pairplot graph

# %%
sns.pairplot(subset_df)
# Out:
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/zmc/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['cancellation_policy'].unique()
# Out:
# array(['strict', 'moderate', 'flexible', 'super_strict_30',
#        'super_strict_60'], dtype=object)

# %% [markdown]
# ### Nine Graphs

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame

# List of property type columns
property_type_columns = [col for col in df_encoded.columns if col.startswith('property_type_')]

# Create an empty dictionary to store median prices for each property type
median_prices_by_property_type = {}

# Calculate median price for each property type
for col in property_type_columns:
    median_price = df_encoded[df_encoded[col] == 1]['log_price'].median()
    median_prices_by_property_type[col] = median_price

# Convert dictionary to DataFrame for easier plotting
median_prices_df = pd.DataFrame(list(median_prices_by_property_type.items()), columns=['Property_Type', 'Median_Price'])

# Sort DataFrame by median price
median_prices_df = median_prices_df.sort_values(by='Median_Price', ascending=False)

# Plotting
plt.figure(figsize=(12, 8))
plt.barh(median_prices_df['Property_Type'], median_prices_df['Median_Price'])
plt.xlabel('Median Price')
plt.ylabel('Property Type')
plt.title('Median Price by Property Type')
plt.show()

# %%
# Calculate the median price for each room type
room_type_median_price = df.groupby('room_type')['log_price'].median().sort_values()

room_type_median_price_exp = np.exp(room_type_median_price)

# Plotting
plt.figure(figsize=(10, 6))
room_type_median_price_exp.plot(kind='bar')
plt.title('Median Price of Different Room Types')
plt.xlabel('Room Type')
plt.ylabel('Median Price ($)')
plt.xticks(rotation=45)
plt.grid(axis='y')

plt.show()
